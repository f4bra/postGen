# %% [markdown]
# <a href="https://colab.research.google.com/github/f4bra/postGen/blob/main/Articles_Gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://huggingface.co/bigscience/bloom

# %%
! pip install transformers -q
# Out:
#      |████████████████████████████████| 4.7 MB 7.3 MB/s
#      |████████████████████████████████| 596 kB 73.6 MB/s
#      |████████████████████████████████| 101 kB 12.6 MB/s
#      |████████████████████████████████| 6.6 MB 48.6 MB/s

# %%
# !nvidia-smi
# Out:
# Thu Aug 18 16:39:19 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed

# %%
import torch
torch.set_default_tensor_type(torch.cuda.FloatTensor)

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b3", use_cache=True)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b3")

# %%
set_seed(424242)

# %%
 model.__class__.__name__
# Out:
# 'BloomForCausalLM'

# %%
blogpost_title = 'La importancia de tener una página web'

# %%
prompt = f'Este es un artículo sobre {blogpost_title} \n {blogpost_title}'

# %%
prompt
# Out:
# 'Este es un artículo sobre La importancia de tener una página web \n La importancia de tener una página web'

# %%
input_ids = tokenizer(prompt, return_tensors="pt").to(0)

# %%
sample = model.generate(**input_ids, max_length=10000,  top_k=1, temperature=0.9, repetition_penalty = 3.0, do_sample=True) #,num_beams = 2, num_beam_groups = 2, diversity_penalty = 0.9, top_p=0.1

# %%
print(tokenizer.decode(sample[0], truncate_before_pattern=[r"\n\n^#", "^'''", "\n\n\n"]))
# Out:
# Este es un artículo sobre La importancia de tener una página web
#  La importancia de tener una página web
# La necesidad que tiene la empresa para estar presente en internet y poder llegar a más clientes, ha hecho necesario el desarrollo e implementación del sitio Web. El objetivo principal consiste en:
#
#  Dar información acerca de: productos o servicios ofrecidos por las empresas.
#  Ofrecer al cliente los medios necesarios (como pueden ser: correo electrónico) con respecto a: ofertas especiales u otros beneficios.
#
# El diseño gráfico debe cumplir ciertas características básicas como:
#
#  Tener coherencia entre lo visualmente atractivo como también funcionalidad.
#  Presentar elementos gráficos llamativos pero sin abusar.
#
# En este sentido se puede decir que:
#
#  Las imágenes son muy importantes ya sea porque representan algo importante dentro nuestra marca personal ó simplemente nos permiten transmitir emociones positivas hacia nuestros seguidores.
# ...
